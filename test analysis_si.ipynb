# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns

import statsmodels.api as sm
import statsmodels.formula.api as smf
from sklearn import metrics

pd.options.display.max_columns = 100
pd.options.display.max_rows = 100

# %%
specific_file = None
specific_file = r'/Users/danielablin/Documents/GitHub/Thesis/test_run_2022-11-10_129_300.pickle'
l = [file_name for file_name in os.listdir() if os.path.splitext(file_name)[1] == '.pickle']
groups = 2

base = pd.concat([pd.read_pickle(path) for path in l], axis=0)
base = base[base['l'].apply(lambda x: (x!=0).all())].reset_index(drop=True)

if specific_file:
    base = pd.read_pickle(specific_file)

for col in ['sol', 'sol_gov']:
    base = pd.concat([base.drop(col, axis=1), pd.json_normalize(base[col]).add_suffix('_' + col)], axis=1)
    
for col in ['cost_sol', 'cost_sol_gov']:
    base[col] = base[col].apply(lambda x: x.flatten())
    base[col] = pd.DataFrame(base[col].to_list()).sum(axis=1)
    
base[['d_11', 'd_12', 'd_21', 'd_22']] = pd.DataFrame(np.array(base['d'].to_list()).reshape(base.shape[0], groups**2))
base[['l_1', 'l_2']] = pd.DataFrame(np.array(base['l'].to_list()).reshape(base.shape[0], groups))
base[['v_1', 'v_2']] = pd.DataFrame(np.array(base['v_sol'].to_list()).reshape(base.shape[0], groups))

base['sol_gap'] = base['cost_sol'] - base['cost_sol_gov']
base['l_t'] = base[['l_1', 'l_2']].sum(axis=1)

base['best_sol'] = base.apply(lambda row: 'gov' if row['cost_sol_gov'] < row['cost_sol'] else 'game', axis=1)

# %%
base['d_between'] = 0
base['d_within'] = 0
for p in range(1,groups+1):
    base.eval(f'd_{p} = d_{p}1 + d_{p}2', inplace=True)
    for p2 in range(1,groups+1):
        if p == p2:
            base['d_between'] += base[f'd_{p}{p2}']
        else:
            base['d_within'] += base[f'd_{p}{p2}']

base['l_rate'] = base['l_1'] / base['l_2']

base['d_t'] = pd.DataFrame(np.array(base['d'].to_list()).reshape(base.shape[0], groups**2)).sum(axis=1)

# %%
base.groupby('best_sol')['l_rate'].mean()
# Out:
# best_sol
# game    0.285562
# Name: l_rate, dtype: float64

# %%
base.groupby('best_sol')['best_sol'].count()
# Out:
# best_sol
# game    300
# Name: best_sol, dtype: int64

# %%
test = base.copy()
v = pd.DataFrame(np.array(base['v_sol'].to_list()).reshape(base.shape[0], groups))
test[['v1', 'v2']] = v
test.query('l_rate < 0.95').groupby('best_sol')[['v1','v2']].min()
# Out:
#            v1   v2
# best_sol
# game      1.0  1.0

# %%
base.groupby('best_sol')['sol_gap'].mean()
# Out:
# best_sol
# game    0.0
# Name: sol_gap, dtype: float64

# %%
base.query('best_sol == "gov"')['msg_sol'].unique()
# Out:
# array(['no close solution', 'time out'], dtype=object)

# %%
base['test'] = base[['d_11', 'd_12', 'd_21', 'd_22', 'l_1', 'l_2']].product(axis=1)

# %%
columns = ['l_1', 'l_2', 'l_t', 'sol_gap', 'l_rate', 'best_sol']
sns.pairplot(base[columns], hue='best_sol', diag_kind='hist')

# %%
base.query('best_sol=="game" and l_rate<0.5')[['d_11', 'd_12', 'd_21', 'd_22', 'l_1', 'l_2', 'l_rate']].sort_values('l_rate')
# Out:
#           d_11      d_12      d_21      d_22  l_1   l_2    l_rate
# 937   0.054385  0.221355  0.180768  0.025613  1.5  15.0  0.100000
# 1483  0.025056  0.134516  0.108370  0.207413  2.5  25.0  0.100000
# 265   0.115190  0.228175  0.065683  0.083746  2.0  20.0  0.100000
# 704   0.020268  0.163466  0.038092  0.157866  1.5  15.0  0.100000
# 1494  0.222479  0.150803  0.004765  0.101696  3.0  30.0  0.100000
# ...        ...       ...       ...       ...  ...   ...       ...
# 2095  0.235950  0.096306  0.107275  0.026471  4.5  13.5  0.333333
# 2091  0.217582  0.098786  0.040088  0.230400  4.5  13.5  0.333333
# 457   0.077963  0.022535  0.022975  0.242530  1.5   4.5  0.333333
# 477   0.086028  0.064234  0.055030  0.175034  1.0   3.0  0.333333
# 2006  0.120574  0.054191  0.165098  0.072972  2.0   6.0  0.333333
#
# [2033 rows x 7 columns]

# %%
base.query('best_sol=="gov" and l_rate<0.5')[['d_11', 'd_12', 'd_21', 'd_22', 'l_1', 'l_2', 'l_rate']].sort_values('l_rate')
# Out:
#           d_11      d_12      d_21      d_22  l_1   l_2    l_rate
# 1796  0.216344  0.203078  0.127279  0.223260  2.5  25.0  0.100000
# 1073  0.088949  0.246902  0.208737  0.127716  2.5  25.0  0.100000
# 766   0.141109  0.179454  0.224510  0.200378  2.0  20.0  0.100000
# 1149  0.150691  0.240781  0.138095  0.082563  4.5  45.0  0.100000
# 309   0.239258  0.167837  0.170858  0.063470  1.0  10.0  0.100000
# ...        ...       ...       ...       ...  ...   ...       ...
# 700   0.238499  0.197975  0.249199  0.231173  0.5   1.5  0.333333
# 1215  0.211393  0.196377  0.146888  0.234778  1.5   4.5  0.333333
# 1636  0.029603  0.068238  0.197800  0.200729  2.5   7.5  0.333333
# 1511  0.147283  0.218465  0.231567  0.079277  4.5  13.5  0.333333
# 1582  0.131674  0.242210  0.205810  0.083138  3.5  10.5  0.333333
#
# [388 rows x 7 columns]

# %%
test = base.astype(str)[['T', 'I0', 'l']].sum(axis=1).astype('category')

# %%
test.cat.categories
# Out:
# Index(['4130.019788760396412353[ 2. 12.]', '4130.019788760396412353[ 2. 16.]',
#        '4130.019788760396412353[ 2. 20.]',
#        '4130.019788760396412353[ 2.5 17.5]',
#        '4130.019788760396412353[ 2.5 20. ]',
#        '4130.019788760396412353[ 3. 12.]', '4130.019788760396412353[ 3. 18.]',
#        '4130.019788760396412353[ 3. 30.]',
#        '4130.019788760396412353[ 4.5 22.5]',
#        '4130.019788760396412353[ 4.5 31.5]',
#        ...
#        '9160.0996238667730245[1. 1.]', '9160.0996238667730245[1. 4.]',
#        '9160.0996238667730245[1. 6.]', '9160.0996238667730245[1. 7.]',
#        '9160.0996238667730245[1.5 4.5]', '9160.0996238667730245[1.5 7.5]',
#        '9160.0996238667730245[1.5 9. ]', '9160.0996238667730245[2. 2.]',
#        '9160.0996238667730245[2. 8.]', '9160.0996238667730245[3. 6.]'],
#       dtype='object', length=2572)

# %%
pd.DataFrame(np.array(base['d'].to_list()).reshape(base.shape[0], groups**2)).sum(axis=1)
# Out:
# 0        0.333098
# 1        0.253309
# 2        0.468736
# 3        0.621143
# 4        0.691815
#            ...
# 11349    0.642052
# 11350    0.642052
# 11351    0.642052
# 11352    0.642052
# 11353    0.642052
# Length: 11354, dtype: float64

# %%
base.columns
# Out:
# Index(['T', 'I0', 'd', 'l', 'Recovered_rate', 'ReSusceptible_rate', 'time',
#        'v_sol', 'v_der_sol', 'cost_sol', 'msg_sol', 'test_results.derv_sol',
#        'test_results.cost_derv_sol', 'test_results.solution_sol', 'v_sol_gov',
#        'v_der_sol_gov', 'cost_sol_gov', 'msg_sol_gov',
#        'test_results.derv_sol_gov', 'test_results.cost_derv_sol_gov',
#        'test_results.solution_sol_gov', 'd_11', 'd_12', 'd_21', 'd_22', 'l_1',
#        'l_2', 'sol_gap', 'best_sol', 'd_between', 'd_within', 'd_1', 'd_2',
#        'l_rate'],
#       dtype='object')

# %%
base[columns].isna().sum()
# Out:
# d_t          0
# d_between    0
# d_within     0
# best_sol     0
# sol_gap      0
# l_rate       0
# dtype: int64

# %%
columns = ['d_t', 'd_between', 'd_within', 'sol_gap', 'l_rate']
base_cat = base.copy()
for col in columns:
    base_cat[col] = pd.qcut(base_cat[col], 20, duplicates='drop', labels=False)

# %%
columns = ['d_t', 'd_between', 'd_within', 'best_sol', 'sol_gap', 'l_rate']
sns.pairplot(base[columns], hue='best_sol')
# Out:
# Error in callback <function flush_figures at 0x13f35ff70> (for post_execute):
# KeyboardInterrupt

# %%
18/3
# Out:
# 6.0

# %%
columns = ['d_t', 'd_between', 'd_within', 'best_sol', 'sol_gap', 'l_rate', 'l_1', 'l_2', 'd_11', 'd_12', 'd_21', 'd_22']
test = base_cat[columns].query('best_sol == "game"').merge(base_cat[columns].query('best_sol == "gov"'), on=['d_t', 'd_between', 'd_within', 'l_rate'])
test.query('d_12_x < d_21_x & d_12_y > d_21_y')
# Out:
#       d_t  d_between  d_within best_sol_x  sol_gap_x  l_rate  l_1_x  l_2_x  \
# 0       2          3         5       game          2       3    3.0   18.0
# 1       2          3         5       game          2       3    3.0   18.0
# 2       2          3         5       game          2       3    3.0   18.0
# 3       2          3         5       game          2       3    3.0   18.0
# 4       2          3         5       game          2       3    3.0   18.0
# ...   ...        ...       ...        ...        ...     ...    ...    ...
# 9198    5         13         2       game          3       1    2.5   20.0
# 9205   14          9        16       game          3       0    4.5   40.5
# 9206   15         10        16       game          3       1    1.0    8.0
# 9207   15         10        16       game          3       1    1.0    8.0
# 9208   15         10        16       game          3       1    1.0    8.0
#
#         d_11_x    d_12_x    d_21_x    d_22_x best_sol_y  sol_gap_y  l_1_y  \
# 0     0.007475  0.044458  0.143374  0.137791        gov          6    3.0
# 1     0.007475  0.044458  0.143374  0.137791        gov         12    1.0
# 2     0.007475  0.044458  0.143374  0.137791        gov          9    4.5
# 3     0.007475  0.044458  0.143374  0.137791        gov          6    3.0
# 4     0.007475  0.044458  0.143374  0.137791        gov         12    1.0
# ...        ...       ...       ...       ...        ...        ...    ...
# 9198  0.135541  0.013209  0.101079  0.159162        gov          4    2.0
# 9205  0.039640  0.157483  0.186509  0.198391        gov         10    2.5
# 9206  0.141151  0.111144  0.240548  0.121414        gov         11    3.5
# 9207  0.141151  0.111144  0.240548  0.121414        gov         13    2.5
# 9208  0.141151  0.111144  0.240548  0.121414        gov         11    3.5
#
#       l_2_y    d_11_y    d_12_y    d_21_y    d_22_y
# 0      18.0  0.150957  0.119883  0.057122  0.002485
# 1       6.0  0.120841  0.115340  0.075620  0.032127
# 2      27.0  0.120841  0.115340  0.075620  0.032127
# 3      18.0  0.150957  0.119883  0.057122  0.002485
# 4       6.0  0.120841  0.115340  0.075620  0.032127
# ...     ...       ...       ...       ...       ...
# 9198   16.0  0.239056  0.108650  0.005925  0.059777
# 9205   25.0  0.222160  0.197725  0.145962  0.029291
# 9206   28.0  0.188050  0.203080  0.141509  0.070580
# 9207   20.0  0.238740  0.228651  0.125368  0.023854
# 9208   28.0  0.188050  0.203080  0.141509  0.070580
#
# [1989 rows x 20 columns]

# %%
columns = ['d_t', 'd_between', 'd_within', 'best_sol', 'sol_gap', 'l_rate']
sns.pairplot(base_cat[columns], hue='best_sol')

# %%
sns.lineplot(data=base, x="T", y="sol_gap", ci=36)#, style='nil_nil')

# %%
params = ['T', 'd_11', 'd_12', 'd_21', 'd_22', 'l_1', 'l_2', 'l_rate']
test = base.copy()
cat_params = []
for var in params:
    test[var + '_cat'] = pd.cut(test[var], 5)
    cat_params.append(var + '_cat')

# %%
test.groupby(test[cat_params].astype('str').sum(axis=1))['T'].count().max()
# Out:
# 7

# %%
formula = 'y ~ ' + ' + '.join(cat_params)

mod1 = smf.glm(formula=formula, data=test, family=sm.families.Binomial()).fit()
test['pred'] = mod1.predict(test)
fpr, tpr, thresholds = metrics.roc_curve(test['y'].astype(int), test['pred'])
print('AUC: ', metrics.auc(fpr, tpr))
mod1.summary()
# Out:
# AUC:  0.8165527816114709
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                10979
# Model:                            GLM   Df Residuals:                    10852
# Model Family:                Binomial   Df Model:                          126
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -5682.2
# Date:                Sun, 23 Oct 2022   Deviance:                       11364.
# Time:                        08:26:55   Pearson chi2:                 1.06e+04
# No. Iterations:                   100   Pseudo R-squ. (CS):             0.2936
# Covariance Type:            nonrobust
# =======================================================================================================================
#                                                           coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------------------------
# Intercept                                               6.5741      0.338     19.478      0.000       5.913       7.236
# T_cat[T.Interval(51.85, 101.7, closed='right')]        -2.6870      0.217    -12.366      0.000      -3.113      -2.261
# T_cat[T.Interval(101.7, 151.55, closed='right')]       -3.6446      0.217    -16.810      0.000      -4.070      -3.220
# T_cat[T.Interval(151.55, 201.4, closed='right')]       -4.3227      0.223    -19.412      0.000      -4.759      -3.886
# T_cat[T.Interval(201.4, 251.25, closed='right')]       -4.6232      0.222    -20.866      0.000      -5.057      -4.189
# T_cat[T.Interval(251.25, 301.1, closed='right')]       -4.7548      0.223    -21.308      0.000      -5.192      -4.317
# T_cat[T.Interval(301.1, 350.95, closed='right')]       -4.3720      0.219    -19.963      0.000      -4.801      -3.943
# T_cat[T.Interval(350.95, 400.8, closed='right')]       -4.4901      0.221    -20.319      0.000      -4.923      -4.057
# T_cat[T.Interval(400.8, 450.65, closed='right')]       -4.2038      0.219    -19.229      0.000      -4.632      -3.775
# T_cat[T.Interval(450.65, 500.5, closed='right')]       -4.0038      0.217    -18.447      0.000      -4.429      -3.578
# T_cat[T.Interval(500.5, 550.35, closed='right')]       -3.9632      0.217    -18.249      0.000      -4.389      -3.538
# T_cat[T.Interval(550.35, 600.2, closed='right')]       -3.6471      0.217    -16.808      0.000      -4.072      -3.222
# T_cat[T.Interval(600.2, 650.05, closed='right')]       -3.5182      0.218    -16.173      0.000      -3.945      -3.092
# T_cat[T.Interval(650.05, 699.9, closed='right')]       -3.5355      0.215    -16.439      0.000      -3.957      -3.114
# T_cat[T.Interval(699.9, 749.75, closed='right')]       -3.3586      0.216    -15.532      0.000      -3.782      -2.935
# T_cat[T.Interval(749.75, 799.6, closed='right')]       -3.2111      0.215    -14.942      0.000      -3.632      -2.790
# T_cat[T.Interval(799.6, 849.45, closed='right')]       -3.1412      0.217    -14.484      0.000      -3.566      -2.716
# T_cat[T.Interval(849.45, 899.3, closed='right')]       -2.9390      0.212    -13.841      0.000      -3.355      -2.523
# T_cat[T.Interval(899.3, 949.15, closed='right')]       -2.6925      0.217    -12.384      0.000      -3.119      -2.266
# T_cat[T.Interval(949.15, 999.0, closed='right')]       -2.6392      0.215    -12.303      0.000      -3.060      -2.219
# d_11_cat[T.Interval(0.0125, 0.025, closed='right')]    -0.3913      0.145     -2.707      0.007      -0.675      -0.108
# d_11_cat[T.Interval(0.025, 0.0375, closed='right')]    -0.4178      0.144     -2.898      0.004      -0.700      -0.135
# d_11_cat[T.Interval(0.0375, 0.05, closed='right')]     -0.5857      0.149     -3.922      0.000      -0.878      -0.293
# d_11_cat[T.Interval(0.05, 0.0625, closed='right')]     -0.8853      0.146     -6.060      0.000      -1.172      -0.599
# d_11_cat[T.Interval(0.0625, 0.075, closed='right')]    -1.0704      0.144     -7.422      0.000      -1.353      -0.788
# d_11_cat[T.Interval(0.075, 0.0875, closed='right')]    -0.9842      0.145     -6.786      0.000      -1.268      -0.700
# d_11_cat[T.Interval(0.0875, 0.1, closed='right')]      -1.1062      0.150     -7.371      0.000      -1.400      -0.812
# d_11_cat[T.Interval(0.1, 0.112, closed='right')]       -1.0480      0.145     -7.216      0.000      -1.333      -0.763
# d_11_cat[T.Interval(0.112, 0.125, closed='right')]     -1.1951      0.148     -8.051      0.000      -1.486      -0.904
# d_11_cat[T.Interval(0.125, 0.137, closed='right')]     -1.1358      0.148     -7.653      0.000      -1.427      -0.845
# d_11_cat[T.Interval(0.137, 0.15, closed='right')]      -1.1892      0.147     -8.071      0.000      -1.478      -0.900
# d_11_cat[T.Interval(0.15, 0.162, closed='right')]      -1.2118      0.145     -8.359      0.000      -1.496      -0.928
# d_11_cat[T.Interval(0.162, 0.175, closed='right')]     -1.0399      0.146     -7.101      0.000      -1.327      -0.753
# d_11_cat[T.Interval(0.175, 0.187, closed='right')]     -1.0598      0.147     -7.216      0.000      -1.348      -0.772
# d_11_cat[T.Interval(0.187, 0.2, closed='right')]       -1.2966      0.146     -8.860      0.000      -1.583      -1.010
# d_11_cat[T.Interval(0.2, 0.212, closed='right')]       -1.1189      0.149     -7.495      0.000      -1.411      -0.826
# d_11_cat[T.Interval(0.212, 0.225, closed='right')]     -0.8972      0.143     -6.280      0.000      -1.177      -0.617
# d_11_cat[T.Interval(0.225, 0.237, closed='right')]     -1.3365      0.147     -9.082      0.000      -1.625      -1.048
# d_11_cat[T.Interval(0.237, 0.25, closed='right')]      -1.0071      0.144     -7.004      0.000      -1.289      -0.725
# d_12_cat[T.Interval(0.0125, 0.025, closed='right')]     0.0431      0.144      0.298      0.765      -0.240       0.326
# d_12_cat[T.Interval(0.025, 0.0375, closed='right')]    -0.1439      0.145     -0.994      0.320      -0.428       0.140
# d_12_cat[T.Interval(0.0375, 0.05, closed='right')]     -0.0820      0.143     -0.571      0.568      -0.363       0.199
# d_12_cat[T.Interval(0.05, 0.0625, closed='right')]      0.0710      0.146      0.488      0.626      -0.214       0.356
# d_12_cat[T.Interval(0.0625, 0.075, closed='right')]    -0.1717      0.143     -1.199      0.230      -0.452       0.109
# d_12_cat[T.Interval(0.075, 0.0875, closed='right')]    -0.0183      0.142     -0.129      0.897      -0.297       0.261
# d_12_cat[T.Interval(0.0875, 0.1, closed='right')]      -0.1815      0.146     -1.243      0.214      -0.468       0.105
# d_12_cat[T.Interval(0.1, 0.113, closed='right')]       -0.0917      0.144     -0.635      0.526      -0.375       0.191
# d_12_cat[T.Interval(0.113, 0.125, closed='right')]      0.0375      0.142      0.265      0.791      -0.240       0.316
# d_12_cat[T.Interval(0.125, 0.138, closed='right')]     -0.0710      0.143     -0.497      0.619      -0.351       0.209
# d_12_cat[T.Interval(0.138, 0.15, closed='right')]      -0.2285      0.146     -1.565      0.117      -0.515       0.058
# d_12_cat[T.Interval(0.15, 0.163, closed='right')]      -0.0602      0.143     -0.421      0.674      -0.341       0.221
# d_12_cat[T.Interval(0.163, 0.175, closed='right')]     -0.2998      0.150     -1.997      0.046      -0.594      -0.006
# d_12_cat[T.Interval(0.175, 0.188, closed='right')]     -0.0216      0.146     -0.148      0.883      -0.308       0.265
# d_12_cat[T.Interval(0.188, 0.2, closed='right')]        0.0573      0.143      0.400      0.689      -0.224       0.339
# d_12_cat[T.Interval(0.2, 0.213, closed='right')]       -0.2025      0.146     -1.383      0.167      -0.489       0.084
# d_12_cat[T.Interval(0.213, 0.225, closed='right')]     -0.0418      0.143     -0.292      0.770      -0.322       0.238
# d_12_cat[T.Interval(0.225, 0.237, closed='right')]      0.0279      0.143      0.195      0.845      -0.252       0.308
# d_12_cat[T.Interval(0.237, 0.25, closed='right')]      -0.0283      0.144     -0.197      0.844      -0.310       0.253
# d_21_cat[T.Interval(0.0125, 0.025, closed='right')]    -0.8050      0.154     -5.239      0.000      -1.106      -0.504
# d_21_cat[T.Interval(0.025, 0.0375, closed='right')]    -1.1117      0.156     -7.148      0.000      -1.416      -0.807
# d_21_cat[T.Interval(0.0375, 0.05, closed='right')]     -1.4908      0.153     -9.760      0.000      -1.790      -1.191
# d_21_cat[T.Interval(0.05, 0.0625, closed='right')]     -1.4216      0.151     -9.429      0.000      -1.717      -1.126
# d_21_cat[T.Interval(0.0625, 0.075, closed='right')]    -1.8931      0.155    -12.247      0.000      -2.196      -1.590
# d_21_cat[T.Interval(0.075, 0.0875, closed='right')]    -1.9833      0.152    -13.035      0.000      -2.281      -1.685
# d_21_cat[T.Interval(0.0875, 0.1, closed='right')]      -2.1274      0.155    -13.687      0.000      -2.432      -1.823
# d_21_cat[T.Interval(0.1, 0.113, closed='right')]       -2.1653      0.157    -13.829      0.000      -2.472      -1.858
# d_21_cat[T.Interval(0.113, 0.125, closed='right')]     -2.3367      0.155    -15.118      0.000      -2.640      -2.034
# d_21_cat[T.Interval(0.125, 0.138, closed='right')]     -2.2620      0.153    -14.805      0.000      -2.561      -1.963
# d_21_cat[T.Interval(0.138, 0.15, closed='right')]      -1.9323      0.157    -12.334      0.000      -2.239      -1.625
# d_21_cat[T.Interval(0.15, 0.163, closed='right')]      -2.2330      0.154    -14.533      0.000      -2.534      -1.932
# d_21_cat[T.Interval(0.163, 0.175, closed='right')]     -2.0393      0.152    -13.415      0.000      -2.337      -1.741
# d_21_cat[T.Interval(0.175, 0.188, closed='right')]     -1.8849      0.152    -12.361      0.000      -2.184      -1.586
# d_21_cat[T.Interval(0.188, 0.2, closed='right')]       -2.0270      0.155    -13.080      0.000      -2.331      -1.723
# d_21_cat[T.Interval(0.2, 0.212, closed='right')]       -1.9832      0.152    -13.025      0.000      -2.282      -1.685
# d_21_cat[T.Interval(0.212, 0.225, closed='right')]     -1.9987      0.153    -13.100      0.000      -2.298      -1.700
# d_21_cat[T.Interval(0.225, 0.237, closed='right')]     -1.9722      0.156    -12.635      0.000      -2.278      -1.666
# d_21_cat[T.Interval(0.237, 0.25, closed='right')]      -1.9673      0.152    -12.904      0.000      -2.266      -1.668
# d_22_cat[T.Interval(0.0125, 0.025, closed='right')]    -0.1408      0.159     -0.887      0.375      -0.452       0.170
# d_22_cat[T.Interval(0.025, 0.0375, closed='right')]    -0.0363      0.157     -0.231      0.817      -0.344       0.271
# d_22_cat[T.Interval(0.0375, 0.05, closed='right')]     -0.0782      0.155     -0.505      0.614      -0.382       0.226
# d_22_cat[T.Interval(0.05, 0.0625, closed='right')]      0.0933      0.157      0.594      0.552      -0.214       0.401
# d_22_cat[T.Interval(0.0625, 0.075, closed='right')]     0.3140      0.150      2.087      0.037       0.019       0.609
# d_22_cat[T.Interval(0.075, 0.0875, closed='right')]     0.4092      0.149      2.747      0.006       0.117       0.701
# d_22_cat[T.Interval(0.0875, 0.1, closed='right')]       0.6802      0.154      4.405      0.000       0.378       0.983
# d_22_cat[T.Interval(0.1, 0.113, closed='right')]        0.8321      0.150      5.553      0.000       0.538       1.126
# d_22_cat[T.Interval(0.113, 0.125, closed='right')]      0.6474      0.154      4.191      0.000       0.345       0.950
# d_22_cat[T.Interval(0.125, 0.138, closed='right')]      0.7664      0.148      5.187      0.000       0.477       1.056
# d_22_cat[T.Interval(0.138, 0.15, closed='right')]       1.0429      0.150      6.966      0.000       0.749       1.336
# d_22_cat[T.Interval(0.15, 0.162, closed='right')]       1.0698      0.148      7.223      0.000       0.780       1.360
# d_22_cat[T.Interval(0.162, 0.175, closed='right')]      1.2354      0.154      8.040      0.000       0.934       1.537
# d_22_cat[T.Interval(0.175, 0.187, closed='right')]      1.6194      0.149     10.840      0.000       1.327       1.912
# d_22_cat[T.Interval(0.187, 0.2, closed='right')]        1.6375      0.149     11.000      0.000       1.346       1.929
# d_22_cat[T.Interval(0.2, 0.212, closed='right')]        1.8001      0.150     11.978      0.000       1.506       2.095
# d_22_cat[T.Interval(0.212, 0.225, closed='right')]      1.9072      0.152     12.582      0.000       1.610       2.204
# d_22_cat[T.Interval(0.225, 0.237, closed='right')]      1.8255      0.152     12.030      0.000       1.528       2.123
# d_22_cat[T.Interval(0.237, 0.25, closed='right')]       2.1840      0.155     14.064      0.000       1.880       2.488
# l_1_cat[T.Interval(0.7, 0.9, closed='right')]        1.264e-16   7.64e-17      1.654      0.098   -2.34e-17    2.76e-16
# l_1_cat[T.Interval(0.9, 1.1, closed='right')]          -1.2526      0.144     -8.708      0.000      -1.535      -0.971
# l_1_cat[T.Interval(1.1, 1.3, closed='right')]        7.557e-17   7.84e-17      0.964      0.335   -7.81e-17    2.29e-16
# l_1_cat[T.Interval(1.3, 1.5, closed='right')]          -1.7360      0.183     -9.493      0.000      -2.094      -1.378
# l_1_cat[T.Interval(1.5, 1.7, closed='right')]        4.938e-17   4.94e-17      0.999      0.318   -4.75e-17    1.46e-16
# l_1_cat[T.Interval(1.7, 1.9, closed='right')]        1.356e-16   6.62e-17      2.047      0.041    5.77e-18    2.65e-16
# l_1_cat[T.Interval(1.9, 2.1, closed='right')]          -1.9180      0.214     -8.947      0.000      -2.338      -1.498
# l_1_cat[T.Interval(2.1, 2.3, closed='right')]        3.002e-16   1.09e-16      2.758      0.006    8.69e-17    5.14e-16
# l_1_cat[T.Interval(2.3, 2.5, closed='right')]          -2.1561      0.243     -8.885      0.000      -2.632      -1.680
# l_1_cat[T.Interval(2.5, 2.7, closed='right')]        4.547e-17   6.96e-17      0.653      0.514    -9.1e-17    1.82e-16
# l_1_cat[T.Interval(2.7, 2.9, closed='right')]        7.537e-17   6.27e-17      1.203      0.229   -4.74e-17    1.98e-16
# l_1_cat[T.Interval(2.9, 3.1, closed='right')]          -2.3127      0.272     -8.496      0.000      -2.846      -1.779
# l_1_cat[T.Interval(3.1, 3.3, closed='right')]       -1.861e-17   5.27e-17     -0.353      0.724   -1.22e-16    8.48e-17
# l_1_cat[T.Interval(3.3, 3.5, closed='right')]          -2.3555      0.291     -8.094      0.000      -2.926      -1.785
# l_1_cat[T.Interval(3.5, 3.7, closed='right')]       -7.922e-17   4.88e-17     -1.623      0.105   -1.75e-16    1.64e-17
# l_1_cat[T.Interval(3.7, 3.9, closed='right')]        1.335e-16    5.5e-17      2.430      0.015    2.58e-17    2.41e-16
# l_1_cat[T.Interval(3.9, 4.1, closed='right')]          -2.6733      0.307     -8.707      0.000      -3.275      -2.072
# l_1_cat[T.Interval(4.1, 4.3, closed='right')]       -1.908e-17   3.61e-17     -0.529      0.597   -8.98e-17    5.16e-17
# l_1_cat[T.Interval(4.3, 4.5, closed='right')]          -2.5442      0.310     -8.213      0.000      -3.151      -1.937
# l_2_cat[T.Interval(2.725, 4.95, closed='right')]       -0.4493      0.152     -2.965      0.003      -0.746      -0.152
# l_2_cat[T.Interval(4.95, 7.175, closed='right')]       -0.2855      0.212     -1.348      0.178      -0.701       0.130
# l_2_cat[T.Interval(7.175, 9.4, closed='right')]        -0.0580      0.253     -0.229      0.819      -0.553       0.438
# l_2_cat[T.Interval(9.4, 11.625, closed='right')]       -0.0654      0.287     -0.228      0.820      -0.628       0.497
# l_2_cat[T.Interval(11.625, 13.85, closed='right')]      0.1824      0.306      0.595      0.552      -0.418       0.783
# l_2_cat[T.Interval(13.85, 16.075, closed='right')]      0.1721      0.334      0.516      0.606      -0.482       0.826
# l_2_cat[T.Interval(16.075, 18.3, closed='right')]       0.2442      0.360      0.678      0.498      -0.461       0.950
# l_2_cat[T.Interval(18.3, 20.525, closed='right')]       0.4225      0.375      1.125      0.260      -0.313       1.158
# l_2_cat[T.Interval(20.525, 22.75, closed='right')]      0.5384      0.390      1.380      0.168      -0.226       1.303
# l_2_cat[T.Interval(22.75, 24.975, closed='right')]      0.3148      0.424      0.742      0.458      -0.516       1.146
# l_2_cat[T.Interval(24.975, 27.2, closed='right')]       0.7233      0.407      1.775      0.076      -0.075       1.522
# l_2_cat[T.Interval(27.2, 29.425, closed='right')]       0.6938      0.452      1.534      0.125      -0.193       1.580
# l_2_cat[T.Interval(29.425, 31.65, closed='right')]      0.3814      0.438      0.872      0.383      -0.476       1.239
# l_2_cat[T.Interval(31.65, 33.875, closed='right')]      0.6503      0.501      1.299      0.194      -0.331       1.631
# l_2_cat[T.Interval(33.875, 36.1, closed='right')]       0.5300      0.448      1.183      0.237      -0.348       1.408
# l_2_cat[T.Interval(36.1, 38.325, closed='right')]            0          0        nan        nan           0           0
# l_2_cat[T.Interval(38.325, 40.55, closed='right')]      0.5489      0.465      1.181      0.238      -0.362       1.460
# l_2_cat[T.Interval(40.55, 42.775, closed='right')]           0          0        nan        nan           0           0
# l_2_cat[T.Interval(42.775, 45.0, closed='right')]       0.4118      0.507      0.812      0.417      -0.582       1.405
# l_rate_cat[T.Interval(0.145, 0.19, closed='right')]     0.3235      0.096      3.365      0.001       0.135       0.512
# l_rate_cat[T.Interval(0.19, 0.235, closed='right')]     0.4651      0.115      4.034      0.000       0.239       0.691
# l_rate_cat[T.Interval(0.235, 0.28, closed='right')]     0.6380      0.137      4.651      0.000       0.369       0.907
# l_rate_cat[T.Interval(0.28, 0.325, closed='right')]          0          0        nan        nan           0           0
# l_rate_cat[T.Interval(0.325, 0.37, closed='right')]     0.8643      0.167      5.162      0.000       0.536       1.193
# l_rate_cat[T.Interval(0.37, 0.415, closed='right')]          0          0        nan        nan           0           0
# l_rate_cat[T.Interval(0.415, 0.46, closed='right')]          0          0        nan        nan           0           0
# l_rate_cat[T.Interval(0.46, 0.505, closed='right')]     1.3495      0.217      6.214      0.000       0.924       1.775
# l_rate_cat[T.Interval(0.505, 0.55, closed='right')]          0          0        nan        nan           0           0
# l_rate_cat[T.Interval(0.55, 0.595, closed='right')]          0          0        nan        nan           0           0
# l_rate_cat[T.Interval(0.595, 0.64, closed='right')]          0          0        nan        nan           0           0
# l_rate_cat[T.Interval(0.64, 0.685, closed='right')]          0          0        nan        nan           0           0
# l_rate_cat[T.Interval(0.685, 0.73, closed='right')]          0          0        nan        nan           0           0
# l_rate_cat[T.Interval(0.73, 0.775, closed='right')]          0          0        nan        nan           0           0
# l_rate_cat[T.Interval(0.775, 0.82, closed='right')]          0          0        nan        nan           0           0
# l_rate_cat[T.Interval(0.82, 0.865, closed='right')]          0          0        nan        nan           0           0
# l_rate_cat[T.Interval(0.865, 0.91, closed='right')]          0          0        nan        nan           0           0
# l_rate_cat[T.Interval(0.91, 0.955, closed='right')]          0          0        nan        nan           0           0
# l_rate_cat[T.Interval(0.955, 1.0, closed='right')]      1.8766      0.307      6.108      0.000       1.274       2.479
# =======================================================================================================================
# """

# %%
0.91*2-1
# Out:
# 0.8200000000000001

# %%
sns.pairplot(test[['best_sol', 'pred']], hue='best_sol')

# %%
hm_test = base.query('cost_sol_gov > cost_sol & msg_sol_gov == "found solution"')
hm_test.set_index(['d_11', 'd_12'], inplace=True)

# %%
sns.heatmap(test.query('best_sol=="game"').drop('best_sol', axis=1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [20], in <cell line: 1>()
# ----> 1 sns.heatmap(test.query('best_sol=="game"').drop('best_sol', axis=1))
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/matrix.py:540, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     362 """Plot rectangular data as a color-encoded matrix.
#     363
#     364 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     537     ...     ax = sns.heatmap(corr, mask=mask, vmax=.3, square=True)
#     538 """
#     539 # Initialize the plotter object
# --> 540 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     541                       annot_kws, cbar, cbar_kws, xticklabels,
#     542                       yticklabels, mask)
#     544 # Add the pcolormesh kwargs here
#     545 kwargs["linewidths"] = linewidths
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/matrix.py:159, in _HeatMapper.__init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     156 self.ylabel = ylabel if ylabel is not None else ""
#     158 # Determine good default values for the colormapping
# --> 159 self._determine_cmap_params(plot_data, vmin, vmax,
#     160                             cmap, center, robust)
#     162 # Sort out the annotations
#     163 if annot is None or annot is False:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/matrix.py:193, in _HeatMapper._determine_cmap_params(self, plot_data, vmin, vmax, cmap, center, robust)
#     190 """Use some heuristics to set good defaults for colorbar and range."""
#     192 # plot_data is a np.ma.array instance
# --> 193 calc_data = plot_data.astype(float).filled(np.nan)
#     194 if vmin is None:
#     195     if robust:
#
# ValueError: could not convert string to float: 'd_11'

# %%
base.query('cost_sol > cost_sol_gov')[['d_11', 'd_12', 'd_21', 'd_22']].sum(axis=1).mean()
# Out:
# 0.5352548689346586

# %%
base.query('cost_sol < cost_sol_gov')[['d_11', 'd_12', 'd_21', 'd_22']].sum(axis=1).mean()
# Out:
# 0.4258546243229284

# %%
base.query('cost_sol > cost_sol_gov').eval('d_12*d_21').mean()
# Out:
# 0.018343999469177436

# %%
base.query('cost_sol > cost_sol_gov')[['d_11', 'd_22', 'T']].mean()
# Out:
# d_11      0.140039
# d_22      0.123119
# T       553.483402
# dtype: float64

# %%
base.query('cost_sol < cost_sol_gov').eval('d_12*d_21').mean()
# Out:
# 0.004261639915904168

# %%
base
# Out:
#         T        I0                                                  d  \
# 0     914  0.037480  [[0.8565816349272409, 0.6292831855177051], [0....
# 1     210  0.002814  [[0.1811095865877227, 0.8615772933961338], [0....
# 2     448  0.092969  [[0.27210870926413344, 0.7953386076766586], [0...
# 3     647  0.072381  [[0.3221893262459786, 0.9652239563946082], [0....
# 4     458  0.051370  [[0.9731576326301973, 0.2951818004700274], [0....
# ...   ...       ...                                                ...
# 2947  792  0.025416  [[0.8212704864063497, 0.2837052908809725], [0....
# 2948  400  0.017882  [[0.11898628366519559, 0.45504947518363503], [...
# 2949  903  0.075246  [[0.3744280344312455, 0.6485019550454362], [0....
# 2950  657  0.090897  [[0.49718973502944186, 0.7011242546638777], [0...
# 2951  502  0.050154  [[0.9440862024170654, 0.5733084192533862], [0....
#
#                l  Recovered_rate  ReSusceptible_rate       time  \
# 0     [50, 2300]               0                   0  29.335019
# 1      [77, 154]               0                   0   3.043460
# 2     [46, 1702]               0                   0  12.776767
# 3      [38, 798]               0                   0  16.529536
# 4        [7, 35]               0                   0   4.466413
# ...          ...             ...                 ...        ...
# 2947   [20, 140]               0                   0   9.007427
# 2948   [50, 550]               0                   0   2.094115
# 2949  [87, 2088]               0                   0   6.991305
# 2950  [33, 1551]               0                   0   3.632560
# 2951   [60, 600]               0                   0   2.249356
#
#                                                   v_sol  \
# 0     [[0.13220528342631357, 0.8116401933875722], [0...
# 1     [[0.5083858220791662, 0.3974059127194974], [0....
# 2     [[0.2179515946389642, 0.7376240890846264], [0....
# 3     [[0.19676556812392365, 0.513278486087027], [0....
# 4     [[0.23738641299054425, 0.9423493485621331], [0...
# ...                                                 ...
# 2947  [[0.18024703769729836, 0.7616229153895309], [0...
# 2948  [[0.42591439004906206, 0.8562517018068917], [0...
# 2949  [[0.13164969703267537, 0.3750856223525718], [0...
# 2950  [[0.1684279186438112, 0.716381084588251], [0.0...
# 2951  [[0.14225492672815443, 0.5725734269966886], [0...
#
#                                               v_der_sol    cost_sol  \
# 0     [[4.804618924936221e-10, -8.510906290837283e-0...  591.848974
# 1     [[-2.7481602327128485e-08, -1.6335377495124703...   22.342767
# 2     [[8.363087999896379e-12, -1.2317620257107365e-...  621.799149
# 3     [[7.09370340246096e-11, -2.727185588469183e-09...  328.989947
# 4     [[3.0604496714659035e-10, -5.625146348720023e-...   51.060503
# ...                                                 ...         ...
# 2947  [[-4.1801584416134574e-10, -9.296900582711487e...   83.575289
# 2948  [[-1.509903313490213e-14, 2.042810365310288e-1...   87.958068
# 2949  [[1.4622969501942862e-10, -9.226468478118477e-...  616.322075
# 2950  [[-2.5579538487363607e-12, 2.311484337269576e-...  622.131160
# 2951  [[1.6704859717719955e-11, 2.604139126560767e-1...  196.407741
#
#              msg_sol                                          v_sol_gov  \
# 0     found solution  [[0.062481132833233526, 0.062481132833233526],...
# 1     found solution  [[0.372188959122877, 0.372188959122877], [0.37...
# 2     found solution  [[0.08044517647035616, 0.08044517647035616], [...
# 3     found solution  [[0.0889846695016355, 0.0889846695016355], [0....
# 4     found solution  [[0.22088180515676975, 0.22088180515676975], [...
# ...              ...                                                ...
# 2947  found solution  [[0.15537822189308395, 0.15537822189308395], [...
# 2948  found solution  [[0.22615422669284008, 0.22615422669284008], [...
# 2949  found solution  [[0.06294028947463672, 0.06294028947463672], [...
# 2950  found solution  [[0.09970753370066586, 0.09970753370066586], [...
# 2951  found solution  [[0.1297999833936732, 0.1297999833936732], [0....
#
#                                           v_der_sol_gov  cost_sol_gov  \
# 0     [[-239.78417793861823, -250.21161963344957], [...    316.343050
# 1     [[-5.350097044444526, -2.5515503095256253], [-...     20.813578
# 2     [[-148.10193159888706, -145.07554906301644], [...    450.403564
# 3     [[-117.29241219513654, -112.9960958740204], [9...    229.319828
# 4     [[-7.448328917304595, -18.637151466984033], [-...     39.520211
# ...                                                 ...           ...
# 2947  [[-24.046523310038427, -38.43112421111843], [-...     58.739820
# 2948  [[-17.2696117909372, -15.22442606717092], [26....     64.403508
# 2949  [[-230.19585838102168, -233.5574628223527], [-...    473.486791
# 2950  [[-83.46315812720917, -90.22237384507537], [22...    449.958674
# 2951  [[-17.87531675340994, -48.8495066811421], [107...    162.593428
#
#          msg_sol_gov      d_11      d_12      d_21      d_22
# 0     found solution  0.856582  0.629283  0.483606  0.908240
# 1     found solution  0.181110  0.861577  0.150991  0.959984
# 2     found solution  0.272109  0.795339  0.902819  0.237061
# 3     found solution  0.322189  0.965224  0.740347  0.458198
# 4     found solution  0.973158  0.295182  0.260556  0.909412
# ...              ...       ...       ...       ...       ...
# 2947  found solution  0.821270  0.283705  0.229973  0.869230
# 2948  found solution  0.118986  0.455049  0.437304  0.121604
# 2949  found solution  0.374428  0.648502  0.332261  0.522544
# 2950  found solution  0.497190  0.701124  0.390621  0.036780
# 2951  found solution  0.944086  0.573308  0.747356  0.049636
#
# [2952 rows x 19 columns]

# %%
base.query('cost_sol < cost_sol_gov')[['d_11', 'd_22', 'T']].mean()
# Out:
# d_11      0.502530
# d_22      0.172665
# T       567.394737
# dtype: float64

# %%
base.query('cost_sol < cost_sol_gov').shape
# Out:
# (76, 19)

# %%
base.query('cost_sol > cost_sol_gov').shape
# Out:
# (2876, 19)
